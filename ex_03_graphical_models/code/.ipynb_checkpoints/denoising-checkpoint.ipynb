# %% [markdown]
# # Image Denoising
#
# You are given a noisy binary image ($10 \times 10$ pixels) which you want to denoise.
# <table><tr>
# <td> <img src="gfx/camera_lego.jpg" width="250"/> </td>
# <td> <img src="gfx/image_noisy_large.png" width="200"/> </td>
# </tr></table>
#
# Make use of the Ising model for that purpose where neighboring pixels are encouraged to take the same value:
# $$p(x_1,\dots,x_{100}) \propto \exp \left\{\sum_{i=1}^{100} \psi_i(x_i) + \sum_{i\sim j} \psi_{ij} (x_i,x_j) \right\}$$
#
# Here, $i$ is the pixel index and $i\sim j$ are neighboring pixels on a 4-connected grid. The unary term $\psi_i(x_i) = [x_i = o_i]$ models the observation at pixel $i$, and the pairwise term is the Ising prior $\psi_{ij}(x_i,x_j) = \alpha \cdot [x_i = x_j]$, where $\alpha$ controls the strength of the interaction/smoothing. Because we have large number of variables in this exercise, we use logarithm factors to avoid potential numerical underflow issues.
#
# The code already contains the implementation of the Max-Product Belief Propagation Algorithm for general structured Markov Random Fields.
# Carefully study the code, understand all the data structures. The pseudocode for this algorithm is specified in the following.
#
# **Inputs:**
# * `num_vars`, `num_states`, `factors`, `msg_fv`, `msg_vf`, `ne_var`
#
# **Outputs:**
# * `max_marginals`: `num_vars` x `num_states` array of estimated max-marginals
# * `map_est`: array comprising the estimated MAP state of each variable
#
# **Algorithm Pseudocode:**
# * For `N=30` iterations do:
#  * Update all unary factor-to-variable messages: $\lambda_{f\rightarrow x}(x) = f(x)$
#  * Update all pairwise factor-to-variable messages: $\lambda_{f\rightarrow x}(x) = \max_y \left[f(x,y)+\lambda_{y\rightarrow f}(y)\right]$
#  * Update all variable-to-factor messages: $\lambda_{x\rightarrow f}(x) = \sum_{g\in\{ ne(x)\setminus f\}}\lambda_{g\rightarrow x}(x)$
#
# * Calculate Max-Marginals: $\gamma_x(x) = \sum_{g\in\{ ne(x)\}}\lambda_{g\rightarrow x}(x)$
# * Calculate MAP Solution: $x^* = \underset{x}{\mathrm{argmax}} ~ \gamma_x(x)$

# %%
# import modules
import numpy as np
import matplotlib.pyplot as plt
import imageio

# load and plot input image
img = imageio.imread('gfx/image.png')/255
plt.imshow(img,interpolation='nearest');
plt.gray()
plt.show()

# %% [markdown]
# Set Model Parameters & Create Factors
#  * `num_vars`: number of variables in MRF
#  * `num_states`: number of states for each variable (binary -> num_states=2)
#  * `factors`: list of dictionaries where each entry of the list comprises two variables: (`vars` = array of variables involved, `vals` = vector/matrix specifying the vector)
#
# ### Task 1
#
# Add the unary and pairwise factors according to the formula given in the beginning.

# %%
# model parameters
[h,w] = img.shape # get width & height of image
num_vars = w*h    # number of variables = width * height
num_states = 2    # binary segmentation -> two states

# initialize factors (list of dictionaries), each factor comprises:
#   vars: array of variables involved
#   vals: vector/matrix of factor values
factors = []

# add unary factors
for u in range(w):
  for v in range(h):
    # 降维减小存储空间
    factors.append({'vars':[v*w+u], 'vals':np.array([1-img[v,u],img[v,u]])})

# add pairwise factors
alpha = 0.4 # smoothness weight
E = alpha*np.array([[1,0],[0,1]]) # energy matrix for pairwise factor
for u in range(w):
  for v in range(h):
    if v<h-1:#竖直
      factors.append({'vars':np.array([v*w+u,(v+1)*w+u]), 'vals':E})
    if u<w-1:#水平
      factors.append({'vars':np.array([v*w+u,v*w+u+1]), 'vals':E})

# %%
factors
# Out:
# [{'vars': [0], 'vals': array([0., 1.])},
#  {'vars': [10], 'vals': array([0., 1.])},
#  {'vars': [20], 'vals': array([1., 0.])},
#  {'vars': [30], 'vals': array([0., 1.])},
#  {'vars': [40], 'vals': array([1., 0.])},
#  {'vars': [50], 'vals': array([0., 1.])},
#  {'vars': [60], 'vals': array([1., 0.])},
#  {'vars': [70], 'vals': array([0., 1.])},
#  {'vars': [80], 'vals': array([0., 1.])},
#  {'vars': [90], 'vals': array([0., 1.])},
#  {'vars': [1], 'vals': array([0., 1.])},
#  {'vars': [11], 'vals': array([0., 1.])},
#  {'vars': [21], 'vals': array([0., 1.])},
#  {'vars': [31], 'vals': array([0., 1.])},
#  {'vars': [41], 'vals': array([0., 1.])},
#  {'vars': [51], 'vals': array([0., 1.])},
#  {'vars': [61], 'vals': array([0., 1.])},
#  {'vars': [71], 'vals': array([1., 0.])},
#  {'vars': [81], 'vals': array([0., 1.])},
#  {'vars': [91], 'vals': array([1., 0.])},
#  {'vars': [2], 'vals': array([1., 0.])},
#  {'vars': [12], 'vals': array([0., 1.])},
#  {'vars': [22], 'vals': array([0., 1.])},
#  {'vars': [32], 'vals': array([1., 0.])},
#  {'vars': [42], 'vals': array([1., 0.])},
#  {'vars': [52], 'vals': array([1., 0.])},
#  {'vars': [62], 'vals': array([0., 1.])},
#  {'vars': [72], 'vals': array([0., 1.])},
#  {'vars': [82], 'vals': array([1., 0.])},
#  {'vars': [92], 'vals': array([1., 0.])},
#  {'vars': [3], 'vals': array([0., 1.])},
#  {'vars': [13], 'vals': array([0., 1.])},
#  {'vars': [23], 'vals': array([1., 0.])},
#  {'vars': [33], 'vals': array([1., 0.])},
#  {'vars': [43], 'vals': array([0., 1.])},
#  {'vars': [53], 'vals': array([1., 0.])},
#  {'vars': [63], 'vals': array([1., 0.])},
#  {'vars': [73], 'vals': array([0., 1.])},
#  {'vars': [83], 'vals': array([1., 0.])},
#  {'vars': [93], 'vals': array([0., 1.])},
#  {'vars': [4], 'vals': array([0., 1.])},
#  {'vars': [14], 'vals': array([1., 0.])},
#  {'vars': [24], 'vals': array([0., 1.])},
#  {'vars': [34], 'vals': array([1., 0.])},
#  {'vars': [44], 'vals': array([1., 0.])},
#  {'vars': [54], 'vals': array([1., 0.])},
#  {'vars': [64], 'vals': array([1., 0.])},
#  {'vars': [74], 'vals': array([1., 0.])},
#  {'vars': [84], 'vals': array([1., 0.])},
#  {'vars': [94], 'vals': array([1., 0.])},
#  {'vars': [5], 'vals': array([0., 1.])},
#  {'vars': [15], 'vals': array([1., 0.])},
#  {'vars': [25], 'vals': array([1., 0.])},
#  {'vars': [35], 'vals': array([1., 0.])},
#  {'vars': [45], 'vals': array([0., 1.])},
#  {'vars': [55], 'vals': array([0., 1.])},
#  {'vars': [65], 'vals': array([1., 0.])},
#  {'vars': [75], 'vals': array([1., 0.])},
#  {'vars': [85], 'vals': array([1., 0.])},
#  {'vars': [95], 'vals': array([1., 0.])},
#  {'vars': [6], 'vals': array([0., 1.])},
#  {'vars': [16], 'vals': array([0., 1.])},
#  {'vars': [26], 'vals': array([1., 0.])},
#  {'vars': [36], 'vals': array([0., 1.])},
#  {'vars': [46], 'vals': array([1., 0.])},
#  {'vars': [56], 'vals': array([1., 0.])},
#  {'vars': [66], 'vals': array([1., 0.])},
#  {'vars': [76], 'vals': array([0., 1.])},
#  {'vars': [86], 'vals': array([1., 0.])},
#  {'vars': [96], 'vals': array([0., 1.])},
#  {'vars': [7], 'vals': array([1., 0.])},
#  {'vars': [17], 'vals': array([0., 1.])},
#  {'vars': [27], 'vals': array([0., 1.])},
#  {'vars': [37], 'vals': array([1., 0.])},
#  {'vars': [47], 'vals': array([1., 0.])},
#  {'vars': [57], 'vals': array([1., 0.])},
#  {'vars': [67], 'vals': array([0., 1.])},
#  {'vars': [77], 'vals': array([0., 1.])},
#  {'vars': [87], 'vals': array([1., 0.])},
#  {'vars': [97], 'vals': array([1., 0.])},
#  {'vars': [8], 'vals': array([0., 1.])},
#  {'vars': [18], 'vals': array([0., 1.])},
#  {'vars': [28], 'vals': array([0., 1.])},
#  {'vars': [38], 'vals': array([0., 1.])},
#  {'vars': [48], 'vals': array([0., 1.])},
#  {'vars': [58], 'vals': array([0., 1.])},
#  {'vars': [68], 'vals': array([1., 0.])},
#  {'vars': [78], 'vals': array([0., 1.])},
#  {'vars': [88], 'vals': array([0., 1.])},
#  {'vars': [98], 'vals': array([1., 0.])},
#  {'vars': [9], 'vals': array([0., 1.])},
#  {'vars': [19], 'vals': array([1., 0.])},
#  {'vars': [29], 'vals': array([0., 1.])},
#  {'vars': [39], 'vals': array([0., 1.])},
#  {'vars': [49], 'vals': array([0., 1.])},
#  {'vars': [59], 'vals': array([0., 1.])},
#  {'vars': [69], 'vals': array([0., 1.])},
#  {'vars': [79], 'vals': array([0., 1.])},
#  {'vars': [89], 'vals': array([1., 0.])},
#  {'vars': [99], 'vals': array([0., 1.])},
#  {'vars': array([ 0, 10]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([0, 1]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([10, 20]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([10, 11]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([20, 30]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([20, 21]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([30, 40]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([30, 31]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([40, 50]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([40, 41]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([50, 60]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([50, 51]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([60, 70]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([60, 61]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([70, 80]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([70, 71]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([80, 90]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([80, 81]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([90, 91]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([ 1, 11]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([1, 2]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([11, 21]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([11, 12]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([21, 31]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([21, 22]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([31, 41]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([31, 32]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([41, 51]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([41, 42]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([51, 61]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([51, 52]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([61, 71]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([61, 62]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([71, 81]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([71, 72]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([81, 91]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([81, 82]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([91, 92]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([ 2, 12]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([2, 3]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([12, 22]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([12, 13]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([22, 32]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([22, 23]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([32, 42]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([32, 33]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([42, 52]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([42, 43]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([52, 62]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([52, 53]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([62, 72]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([62, 63]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([72, 82]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([72, 73]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([82, 92]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([82, 83]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([92, 93]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([ 3, 13]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([3, 4]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([13, 23]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([13, 14]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([23, 33]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([23, 24]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([33, 43]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([33, 34]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([43, 53]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([43, 44]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([53, 63]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([53, 54]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([63, 73]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([63, 64]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([73, 83]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([73, 74]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([83, 93]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([83, 84]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([93, 94]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([ 4, 14]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([4, 5]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([14, 24]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([14, 15]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([24, 34]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([24, 25]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([34, 44]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([34, 35]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([44, 54]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([44, 45]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([54, 64]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([54, 55]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([64, 74]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([64, 65]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([74, 84]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([74, 75]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([84, 94]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([84, 85]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([94, 95]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([ 5, 15]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([5, 6]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([15, 25]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([15, 16]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([25, 35]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([25, 26]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([35, 45]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([35, 36]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([45, 55]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([45, 46]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([55, 65]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([55, 56]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([65, 75]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([65, 66]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([75, 85]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([75, 76]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([85, 95]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([85, 86]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([95, 96]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([ 6, 16]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([6, 7]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([16, 26]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([16, 17]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([26, 36]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([26, 27]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([36, 46]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([36, 37]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([46, 56]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([46, 47]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([56, 66]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([56, 57]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([66, 76]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([66, 67]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([76, 86]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([76, 77]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([86, 96]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([86, 87]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([96, 97]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([ 7, 17]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([7, 8]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([17, 27]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([17, 18]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([27, 37]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([27, 28]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([37, 47]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([37, 38]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([47, 57]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([47, 48]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([57, 67]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([57, 58]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([67, 77]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([67, 68]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([77, 87]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([77, 78]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([87, 97]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([87, 88]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([97, 98]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([ 8, 18]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([8, 9]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([18, 28]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([18, 19]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([28, 38]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([28, 29]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([38, 48]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([38, 39]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([48, 58]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([48, 49]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([58, 68]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([58, 59]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([68, 78]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([68, 69]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([78, 88]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([78, 79]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([88, 98]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([88, 89]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([98, 99]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([ 9, 19]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([19, 29]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([29, 39]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([39, 49]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([49, 59]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([59, 69]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([69, 79]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([79, 89]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])},
#  {'vars': array([89, 99]),
#   'vals': array([[0.4, 0. ],
#          [0. , 0.4]])}]

# %% [markdown]
# Initialize Messages
#  * `msg_fv`: dictionary of all messages from factors to variables
#  * `msg_vf`: dictionary of all messages from variables to factors
#  * `ne_var`: list which comprises the neighboring factors of each variable

# %%
# initialize all messages
msg_fv = {} # f->v messages (dictionary)
msg_vf = {} # v->f messages (dictionary)
ne_var = [[] for i in range(num_vars)] # neighboring factors of variables (list of list)

# set messages to zero; determine factors neighboring each variable
for [f_idx,f] in enumerate(factors):
    for v_idx in f['vars']: # 100个之后每个会拆成2个
        msg_fv[(f_idx,v_idx)] = np.zeros(num_states) # factor->variable message
        msg_vf[(v_idx,f_idx)] = np.zeros(num_states) # variable->factor message
        ne_var[v_idx].append(f_idx) # factors neighboring variable v_idx

# status message
print("Messages initialized!")
# Out:
# Messages initialized!

# %%
msg_vf
# Out:
# {(0, 0): array([0., 0.]),
#  (10, 1): array([0., 0.]),
#  (20, 2): array([0., 0.]),
#  (30, 3): array([0., 0.]),
#  (40, 4): array([0., 0.]),
#  (50, 5): array([0., 0.]),
#  (60, 6): array([0., 0.]),
#  (70, 7): array([0., 0.]),
#  (80, 8): array([0., 0.]),
#  (90, 9): array([0., 0.]),
#  (1, 10): array([0., 0.]),
#  (11, 11): array([0., 0.]),
#  (21, 12): array([0., 0.]),
#  (31, 13): array([0., 0.]),
#  (41, 14): array([0., 0.]),
#  (51, 15): array([0., 0.]),
#  (61, 16): array([0., 0.]),
#  (71, 17): array([0., 0.]),
#  (81, 18): array([0., 0.]),
#  (91, 19): array([0., 0.]),
#  (2, 20): array([0., 0.]),
#  (12, 21): array([0., 0.]),
#  (22, 22): array([0., 0.]),
#  (32, 23): array([0., 0.]),
#  (42, 24): array([0., 0.]),
#  (52, 25): array([0., 0.]),
#  (62, 26): array([0., 0.]),
#  (72, 27): array([0., 0.]),
#  (82, 28): array([0., 0.]),
#  (92, 29): array([0., 0.]),
#  (3, 30): array([0., 0.]),
#  (13, 31): array([0., 0.]),
#  (23, 32): array([0., 0.]),
#  (33, 33): array([0., 0.]),
#  (43, 34): array([0., 0.]),
#  (53, 35): array([0., 0.]),
#  (63, 36): array([0., 0.]),
#  (73, 37): array([0., 0.]),
#  (83, 38): array([0., 0.]),
#  (93, 39): array([0., 0.]),
#  (4, 40): array([0., 0.]),
#  (14, 41): array([0., 0.]),
#  (24, 42): array([0., 0.]),
#  (34, 43): array([0., 0.]),
#  (44, 44): array([0., 0.]),
#  (54, 45): array([0., 0.]),
#  (64, 46): array([0., 0.]),
#  (74, 47): array([0., 0.]),
#  (84, 48): array([0., 0.]),
#  (94, 49): array([0., 0.]),
#  (5, 50): array([0., 0.]),
#  (15, 51): array([0., 0.]),
#  (25, 52): array([0., 0.]),
#  (35, 53): array([0., 0.]),
#  (45, 54): array([0., 0.]),
#  (55, 55): array([0., 0.]),
#  (65, 56): array([0., 0.]),
#  (75, 57): array([0., 0.]),
#  (85, 58): array([0., 0.]),
#  (95, 59): array([0., 0.]),
#  (6, 60): array([0., 0.]),
#  (16, 61): array([0., 0.]),
#  (26, 62): array([0., 0.]),
#  (36, 63): array([0., 0.]),
#  (46, 64): array([0., 0.]),
#  (56, 65): array([0., 0.]),
#  (66, 66): array([0., 0.]),
#  (76, 67): array([0., 0.]),
#  (86, 68): array([0., 0.]),
#  (96, 69): array([0., 0.]),
#  (7, 70): array([0., 0.]),
#  (17, 71): array([0., 0.]),
#  (27, 72): array([0., 0.]),
#  (37, 73): array([0., 0.]),
#  (47, 74): array([0., 0.]),
#  (57, 75): array([0., 0.]),
#  (67, 76): array([0., 0.]),
#  (77, 77): array([0., 0.]),
#  (87, 78): array([0., 0.]),
#  (97, 79): array([0., 0.]),
#  (8, 80): array([0., 0.]),
#  (18, 81): array([0., 0.]),
#  (28, 82): array([0., 0.]),
#  (38, 83): array([0., 0.]),
#  (48, 84): array([0., 0.]),
#  (58, 85): array([0., 0.]),
#  (68, 86): array([0., 0.]),
#  (78, 87): array([0., 0.]),
#  (88, 88): array([0., 0.]),
#  (98, 89): array([0., 0.]),
#  (9, 90): array([0., 0.]),
#  (19, 91): array([0., 0.]),
#  (29, 92): array([0., 0.]),
#  (39, 93): array([0., 0.]),
#  (49, 94): array([0., 0.]),
#  (59, 95): array([0., 0.]),
#  (69, 96): array([0., 0.]),
#  (79, 97): array([0., 0.]),
#  (89, 98): array([0., 0.]),
#  (99, 99): array([0., 0.]),
#  (0, 100): array([0., 0.]),
#  (10, 100): array([0., 0.]),
#  (0, 101): array([0., 0.]),
#  (1, 101): array([0., 0.]),
#  (10, 102): array([0., 0.]),
#  (20, 102): array([0., 0.]),
#  (10, 103): array([0., 0.]),
#  (11, 103): array([0., 0.]),
#  (20, 104): array([0., 0.]),
#  (30, 104): array([0., 0.]),
#  (20, 105): array([0., 0.]),
#  (21, 105): array([0., 0.]),
#  (30, 106): array([0., 0.]),
#  (40, 106): array([0., 0.]),
#  (30, 107): array([0., 0.]),
#  (31, 107): array([0., 0.]),
#  (40, 108): array([0., 0.]),
#  (50, 108): array([0., 0.]),
#  (40, 109): array([0., 0.]),
#  (41, 109): array([0., 0.]),
#  (50, 110): array([0., 0.]),
#  (60, 110): array([0., 0.]),
#  (50, 111): array([0., 0.]),
#  (51, 111): array([0., 0.]),
#  (60, 112): array([0., 0.]),
#  (70, 112): array([0., 0.]),
#  (60, 113): array([0., 0.]),
#  (61, 113): array([0., 0.]),
#  (70, 114): array([0., 0.]),
#  (80, 114): array([0., 0.]),
#  (70, 115): array([0., 0.]),
#  (71, 115): array([0., 0.]),
#  (80, 116): array([0., 0.]),
#  (90, 116): array([0., 0.]),
#  (80, 117): array([0., 0.]),
#  (81, 117): array([0., 0.]),
#  (90, 118): array([0., 0.]),
#  (91, 118): array([0., 0.]),
#  (1, 119): array([0., 0.]),
#  (11, 119): array([0., 0.]),
#  (1, 120): array([0., 0.]),
#  (2, 120): array([0., 0.]),
#  (11, 121): array([0., 0.]),
#  (21, 121): array([0., 0.]),
#  (11, 122): array([0., 0.]),
#  (12, 122): array([0., 0.]),
#  (21, 123): array([0., 0.]),
#  (31, 123): array([0., 0.]),
#  (21, 124): array([0., 0.]),
#  (22, 124): array([0., 0.]),
#  (31, 125): array([0., 0.]),
#  (41, 125): array([0., 0.]),
#  (31, 126): array([0., 0.]),
#  (32, 126): array([0., 0.]),
#  (41, 127): array([0., 0.]),
#  (51, 127): array([0., 0.]),
#  (41, 128): array([0., 0.]),
#  (42, 128): array([0., 0.]),
#  (51, 129): array([0., 0.]),
#  (61, 129): array([0., 0.]),
#  (51, 130): array([0., 0.]),
#  (52, 130): array([0., 0.]),
#  (61, 131): array([0., 0.]),
#  (71, 131): array([0., 0.]),
#  (61, 132): array([0., 0.]),
#  (62, 132): array([0., 0.]),
#  (71, 133): array([0., 0.]),
#  (81, 133): array([0., 0.]),
#  (71, 134): array([0., 0.]),
#  (72, 134): array([0., 0.]),
#  (81, 135): array([0., 0.]),
#  (91, 135): array([0., 0.]),
#  (81, 136): array([0., 0.]),
#  (82, 136): array([0., 0.]),
#  (91, 137): array([0., 0.]),
#  (92, 137): array([0., 0.]),
#  (2, 138): array([0., 0.]),
#  (12, 138): array([0., 0.]),
#  (2, 139): array([0., 0.]),
#  (3, 139): array([0., 0.]),
#  (12, 140): array([0., 0.]),
#  (22, 140): array([0., 0.]),
#  (12, 141): array([0., 0.]),
#  (13, 141): array([0., 0.]),
#  (22, 142): array([0., 0.]),
#  (32, 142): array([0., 0.]),
#  (22, 143): array([0., 0.]),
#  (23, 143): array([0., 0.]),
#  (32, 144): array([0., 0.]),
#  (42, 144): array([0., 0.]),
#  (32, 145): array([0., 0.]),
#  (33, 145): array([0., 0.]),
#  (42, 146): array([0., 0.]),
#  (52, 146): array([0., 0.]),
#  (42, 147): array([0., 0.]),
#  (43, 147): array([0., 0.]),
#  (52, 148): array([0., 0.]),
#  (62, 148): array([0., 0.]),
#  (52, 149): array([0., 0.]),
#  (53, 149): array([0., 0.]),
#  (62, 150): array([0., 0.]),
#  (72, 150): array([0., 0.]),
#  (62, 151): array([0., 0.]),
#  (63, 151): array([0., 0.]),
#  (72, 152): array([0., 0.]),
#  (82, 152): array([0., 0.]),
#  (72, 153): array([0., 0.]),
#  (73, 153): array([0., 0.]),
#  (82, 154): array([0., 0.]),
#  (92, 154): array([0., 0.]),
#  (82, 155): array([0., 0.]),
#  (83, 155): array([0., 0.]),
#  (92, 156): array([0., 0.]),
#  (93, 156): array([0., 0.]),
#  (3, 157): array([0., 0.]),
#  (13, 157): array([0., 0.]),
#  (3, 158): array([0., 0.]),
#  (4, 158): array([0., 0.]),
#  (13, 159): array([0., 0.]),
#  (23, 159): array([0., 0.]),
#  (13, 160): array([0., 0.]),
#  (14, 160): array([0., 0.]),
#  (23, 161): array([0., 0.]),
#  (33, 161): array([0., 0.]),
#  (23, 162): array([0., 0.]),
#  (24, 162): array([0., 0.]),
#  (33, 163): array([0., 0.]),
#  (43, 163): array([0., 0.]),
#  (33, 164): array([0., 0.]),
#  (34, 164): array([0., 0.]),
#  (43, 165): array([0., 0.]),
#  (53, 165): array([0., 0.]),
#  (43, 166): array([0., 0.]),
#  (44, 166): array([0., 0.]),
#  (53, 167): array([0., 0.]),
#  (63, 167): array([0., 0.]),
#  (53, 168): array([0., 0.]),
#  (54, 168): array([0., 0.]),
#  (63, 169): array([0., 0.]),
#  (73, 169): array([0., 0.]),
#  (63, 170): array([0., 0.]),
#  (64, 170): array([0., 0.]),
#  (73, 171): array([0., 0.]),
#  (83, 171): array([0., 0.]),
#  (73, 172): array([0., 0.]),
#  (74, 172): array([0., 0.]),
#  (83, 173): array([0., 0.]),
#  (93, 173): array([0., 0.]),
#  (83, 174): array([0., 0.]),
#  (84, 174): array([0., 0.]),
#  (93, 175): array([0., 0.]),
#  (94, 175): array([0., 0.]),
#  (4, 176): array([0., 0.]),
#  (14, 176): array([0., 0.]),
#  (4, 177): array([0., 0.]),
#  (5, 177): array([0., 0.]),
#  (14, 178): array([0., 0.]),
#  (24, 178): array([0., 0.]),
#  (14, 179): array([0., 0.]),
#  (15, 179): array([0., 0.]),
#  (24, 180): array([0., 0.]),
#  (34, 180): array([0., 0.]),
#  (24, 181): array([0., 0.]),
#  (25, 181): array([0., 0.]),
#  (34, 182): array([0., 0.]),
#  (44, 182): array([0., 0.]),
#  (34, 183): array([0., 0.]),
#  (35, 183): array([0., 0.]),
#  (44, 184): array([0., 0.]),
#  (54, 184): array([0., 0.]),
#  (44, 185): array([0., 0.]),
#  (45, 185): array([0., 0.]),
#  (54, 186): array([0., 0.]),
#  (64, 186): array([0., 0.]),
#  (54, 187): array([0., 0.]),
#  (55, 187): array([0., 0.]),
#  (64, 188): array([0., 0.]),
#  (74, 188): array([0., 0.]),
#  (64, 189): array([0., 0.]),
#  (65, 189): array([0., 0.]),
#  (74, 190): array([0., 0.]),
#  (84, 190): array([0., 0.]),
#  (74, 191): array([0., 0.]),
#  (75, 191): array([0., 0.]),
#  (84, 192): array([0., 0.]),
#  (94, 192): array([0., 0.]),
#  (84, 193): array([0., 0.]),
#  (85, 193): array([0., 0.]),
#  (94, 194): array([0., 0.]),
#  (95, 194): array([0., 0.]),
#  (5, 195): array([0., 0.]),
#  (15, 195): array([0., 0.]),
#  (5, 196): array([0., 0.]),
#  (6, 196): array([0., 0.]),
#  (15, 197): array([0., 0.]),
#  (25, 197): array([0., 0.]),
#  (15, 198): array([0., 0.]),
#  (16, 198): array([0., 0.]),
#  (25, 199): array([0., 0.]),
#  (35, 199): array([0., 0.]),
#  (25, 200): array([0., 0.]),
#  (26, 200): array([0., 0.]),
#  (35, 201): array([0., 0.]),
#  (45, 201): array([0., 0.]),
#  (35, 202): array([0., 0.]),
#  (36, 202): array([0., 0.]),
#  (45, 203): array([0., 0.]),
#  (55, 203): array([0., 0.]),
#  (45, 204): array([0., 0.]),
#  (46, 204): array([0., 0.]),
#  (55, 205): array([0., 0.]),
#  (65, 205): array([0., 0.]),
#  (55, 206): array([0., 0.]),
#  (56, 206): array([0., 0.]),
#  (65, 207): array([0., 0.]),
#  (75, 207): array([0., 0.]),
#  (65, 208): array([0., 0.]),
#  (66, 208): array([0., 0.]),
#  (75, 209): array([0., 0.]),
#  (85, 209): array([0., 0.]),
#  (75, 210): array([0., 0.]),
#  (76, 210): array([0., 0.]),
#  (85, 211): array([0., 0.]),
#  (95, 211): array([0., 0.]),
#  (85, 212): array([0., 0.]),
#  (86, 212): array([0., 0.]),
#  (95, 213): array([0., 0.]),
#  (96, 213): array([0., 0.]),
#  (6, 214): array([0., 0.]),
#  (16, 214): array([0., 0.]),
#  (6, 215): array([0., 0.]),
#  (7, 215): array([0., 0.]),
#  (16, 216): array([0., 0.]),
#  (26, 216): array([0., 0.]),
#  (16, 217): array([0., 0.]),
#  (17, 217): array([0., 0.]),
#  (26, 218): array([0., 0.]),
#  (36, 218): array([0., 0.]),
#  (26, 219): array([0., 0.]),
#  (27, 219): array([0., 0.]),
#  (36, 220): array([0., 0.]),
#  (46, 220): array([0., 0.]),
#  (36, 221): array([0., 0.]),
#  (37, 221): array([0., 0.]),
#  (46, 222): array([0., 0.]),
#  (56, 222): array([0., 0.]),
#  (46, 223): array([0., 0.]),
#  (47, 223): array([0., 0.]),
#  (56, 224): array([0., 0.]),
#  (66, 224): array([0., 0.]),
#  (56, 225): array([0., 0.]),
#  (57, 225): array([0., 0.]),
#  (66, 226): array([0., 0.]),
#  (76, 226): array([0., 0.]),
#  (66, 227): array([0., 0.]),
#  (67, 227): array([0., 0.]),
#  (76, 228): array([0., 0.]),
#  (86, 228): array([0., 0.]),
#  (76, 229): array([0., 0.]),
#  (77, 229): array([0., 0.]),
#  (86, 230): array([0., 0.]),
#  (96, 230): array([0., 0.]),
#  (86, 231): array([0., 0.]),
#  (87, 231): array([0., 0.]),
#  (96, 232): array([0., 0.]),
#  (97, 232): array([0., 0.]),
#  (7, 233): array([0., 0.]),
#  (17, 233): array([0., 0.]),
#  (7, 234): array([0., 0.]),
#  (8, 234): array([0., 0.]),
#  (17, 235): array([0., 0.]),
#  (27, 235): array([0., 0.]),
#  (17, 236): array([0., 0.]),
#  (18, 236): array([0., 0.]),
#  (27, 237): array([0., 0.]),
#  (37, 237): array([0., 0.]),
#  (27, 238): array([0., 0.]),
#  (28, 238): array([0., 0.]),
#  (37, 239): array([0., 0.]),
#  (47, 239): array([0., 0.]),
#  (37, 240): array([0., 0.]),
#  (38, 240): array([0., 0.]),
#  (47, 241): array([0., 0.]),
#  (57, 241): array([0., 0.]),
#  (47, 242): array([0., 0.]),
#  (48, 242): array([0., 0.]),
#  (57, 243): array([0., 0.]),
#  (67, 243): array([0., 0.]),
#  (57, 244): array([0., 0.]),
#  (58, 244): array([0., 0.]),
#  (67, 245): array([0., 0.]),
#  (77, 245): array([0., 0.]),
#  (67, 246): array([0., 0.]),
#  (68, 246): array([0., 0.]),
#  (77, 247): array([0., 0.]),
#  (87, 247): array([0., 0.]),
#  (77, 248): array([0., 0.]),
#  (78, 248): array([0., 0.]),
#  (87, 249): array([0., 0.]),
#  (97, 249): array([0., 0.]),
#  (87, 250): array([0., 0.]),
#  (88, 250): array([0., 0.]),
#  (97, 251): array([0., 0.]),
#  (98, 251): array([0., 0.]),
#  (8, 252): array([0., 0.]),
#  (18, 252): array([0., 0.]),
#  (8, 253): array([0., 0.]),
#  (9, 253): array([0., 0.]),
#  (18, 254): array([0., 0.]),
#  (28, 254): array([0., 0.]),
#  (18, 255): array([0., 0.]),
#  (19, 255): array([0., 0.]),
#  (28, 256): array([0., 0.]),
#  (38, 256): array([0., 0.]),
#  (28, 257): array([0., 0.]),
#  (29, 257): array([0., 0.]),
#  (38, 258): array([0., 0.]),
#  (48, 258): array([0., 0.]),
#  (38, 259): array([0., 0.]),
#  (39, 259): array([0., 0.]),
#  (48, 260): array([0., 0.]),
#  (58, 260): array([0., 0.]),
#  (48, 261): array([0., 0.]),
#  (49, 261): array([0., 0.]),
#  (58, 262): array([0., 0.]),
#  (68, 262): array([0., 0.]),
#  (58, 263): array([0., 0.]),
#  (59, 263): array([0., 0.]),
#  (68, 264): array([0., 0.]),
#  (78, 264): array([0., 0.]),
#  (68, 265): array([0., 0.]),
#  (69, 265): array([0., 0.]),
#  (78, 266): array([0., 0.]),
#  (88, 266): array([0., 0.]),
#  (78, 267): array([0., 0.]),
#  (79, 267): array([0., 0.]),
#  (88, 268): array([0., 0.]),
#  (98, 268): array([0., 0.]),
#  (88, 269): array([0., 0.]),
#  (89, 269): array([0., 0.]),
#  (98, 270): array([0., 0.]),
#  (99, 270): array([0., 0.]),
#  (9, 271): array([0., 0.]),
#  (19, 271): array([0., 0.]),
#  (19, 272): array([0., 0.]),
#  (29, 272): array([0., 0.]),
#  (29, 273): array([0., 0.]),
#  (39, 273): array([0., 0.]),
#  (39, 274): array([0., 0.]),
#  (49, 274): array([0., 0.]),
#  (49, 275): array([0., 0.]),
#  (59, 275): array([0., 0.]),
#  (59, 276): array([0., 0.]),
#  (69, 276): array([0., 0.]),
#  (69, 277): array([0., 0.]),
#  (79, 277): array([0., 0.]),
#  (79, 278): array([0., 0.]),
#  (89, 278): array([0., 0.]),
#  (89, 279): array([0., 0.]),
#  (99, 279): array([0., 0.])}

# %%
# 每个点与包含该点neighbor关系
ne_var

# %% [markdown]
# Inference: Implementation of the Max-Product Belief Propagation Algorithm as outlined in the Pseudocode in the beginning.

# %%
# run inference
for it in range(30):
  
    # for all factor-to-variable messages do
    for [key,msg] in msg_fv.items():
        
        # shortcuts to variables
        f_idx = key[0] # factor (source)
        v_idx = key[1] # variable (target)
        f_vars = factors[f_idx]['vars'] # variables connected to factor
        f_vals = factors[f_idx]['vals'] # vector/matrix of factor values 

        # unary factor-to-variable message
        if np.size(f_vars)==1:
            msg_fv[(f_idx,v_idx)] = f_vals

        # pairwise factor-to-variable-message
        else:

            # if target variable is first variable of factor
            if v_idx==f_vars[0]:
                msg_in = np.tile(msg_vf[(f_vars[1],f_idx)],(num_states,1))
                msg_fv[(f_idx,v_idx)] = (f_vals+msg_in).max(1) # max over columns

            # if target variable is second variable of factor
            else:
                msg_in = np.tile(msg_vf[(f_vars[0],f_idx)],(num_states,1))
                msg_fv[(f_idx,v_idx)] = (f_vals+msg_in.transpose()).max(0) # max over rows
                
        # normalize
        msg_fv[(f_idx,v_idx)] = msg_fv[(f_idx,v_idx)] - np.mean(msg_fv[(f_idx,v_idx)])

    # for all variable-to-factor messages do
    for [key,msg] in msg_vf.items():
        
        # shortcuts to variables
        v_idx = key[0] # variable (source)
        f_idx = key[1] # factor (target)

        # add messages from all factors send to this variable (except target factor)
        # and send the result to the target factor
        msg_vf[(v_idx,f_idx)] = np.zeros(num_states)
        for f_idx2 in ne_var[v_idx]:
            if f_idx2 != f_idx:
                msg_vf[(v_idx,f_idx)] += msg_fv[(f_idx2,v_idx)]
                
        # normalize
        msg_vf[(v_idx,f_idx)] = msg_vf[(v_idx,f_idx)] - np.mean(msg_vf[(v_idx,f_idx)])
        
# calculate max-marginals (num_vars x num_states matrix)
max_marginals = np.zeros([num_vars,num_states])
for v_idx in range(num_vars):
    
    # add messages from all factors sent to this variable
    max_marginals[v_idx] = np.zeros(num_states)
    for f_idx in ne_var[v_idx]:
        max_marginals[v_idx] += msg_fv[(f_idx,v_idx)]
    #print max_marginals[v_idx]

# get MAP solution
map_est = np.argmax(max_marginals,axis=1)

# %% [markdown]
# Show Inference Results

# %%
# plot MAP estimate
plt.imshow(map_est.reshape(h,w),interpolation='nearest');
plt.gray()
plt.show()

# %% [markdown]
# ### Task 2: Smoothness Prior
#
# Using the code developed above, answer the following questions:
# * Can you recover a noise-free image?
# * With which parameter $\alpha$ is this possible?
# * What happens when you increase or decrease $\alpha$?
# * Show all distinct MAP estimates for $\alpha\in[0,1]$

# %%
# model parameters
[h,w] = img.shape # get width & height of image
num_vars = w*h    # number of variables = width * height
num_states = 2    # binary segmentation -> two states

# initialize factors (list of dictionaries), each factor comprises:
#   vars: array of variables involved
#   vals: vector/matrix of factor values
factors = []

# add unary factors
for u in range(w):
  for v in range(h):
    # 降维减小存储空间
    factors.append({'vars':[v*w+u], 'vals':np.array([1-img[v,u],img[v,u]])})

# add pairwise factors
alpha = 0.4 # smoothness weight    alpha过大会去噪过-过度（eg.>=0.5）过小会去噪不足（eg.<=0.3）
E = alpha*np.array([[1,0],[0,1]]) # energy matrix for pairwise factor
for u in range(w):
  for v in range(h):
    if v<h-1:#竖直
      factors.append({'vars':np.array([v*w+u,(v+1)*w+u]), 'vals':E})
    if u<w-1:#水平
      factors.append({'vars':np.array([v*w+u,v*w+u+1]), 'vals':E})
    
# initialize all messages
msg_fv = {} # f->v messages (dictionary)
msg_vf = {} # v->f messages (dictionary)
ne_var = [[] for i in range(num_vars)] # neighboring factors of variables (list of list)

# set messages to zero; determine factors neighboring each variable
for [f_idx,f] in enumerate(factors):
    for v_idx in f['vars']: # 100个之后每个会拆成2个
        msg_fv[(f_idx,v_idx)] = np.zeros(num_states) # factor->variable message
        msg_vf[(v_idx,f_idx)] = np.zeros(num_states) # variable->factor message
        ne_var[v_idx].append(f_idx) # factors neighboring variable v_idx

# status message
print("Messages initialized!")

# run inference
for it in range(30):
  
    # for all factor-to-variable messages do
    for [key,msg] in msg_fv.items():
        
        # shortcuts to variables
        f_idx = key[0] # factor (source)
        v_idx = key[1] # variable (target)
        f_vars = factors[f_idx]['vars'] # variables connected to factor
        f_vals = factors[f_idx]['vals'] # vector/matrix of factor values 

        # unary factor-to-variable message
        if np.size(f_vars)==1:
            msg_fv[(f_idx,v_idx)] = f_vals

        # pairwise factor-to-variable-message
        else:

            # if target variable is first variable of factor
            if v_idx==f_vars[0]:
                msg_in = np.tile(msg_vf[(f_vars[1],f_idx)],(num_states,1))
                msg_fv[(f_idx,v_idx)] = (f_vals+msg_in).max(1) # max over columns

            # if target variable is second variable of factor
            else:
                msg_in = np.tile(msg_vf[(f_vars[0],f_idx)],(num_states,1))
                msg_fv[(f_idx,v_idx)] = (f_vals+msg_in.transpose()).max(0) # max over rows
                
        # normalize
        msg_fv[(f_idx,v_idx)] = msg_fv[(f_idx,v_idx)] - np.mean(msg_fv[(f_idx,v_idx)])

    # for all variable-to-factor messages do
    for [key,msg] in msg_vf.items():
        
        # shortcuts to variables
        v_idx = key[0] # variable (source)
        f_idx = key[1] # factor (target)

        # add messages from all factors send to this variable (except target factor)
        # and send the result to the target factor
        msg_vf[(v_idx,f_idx)] = np.zeros(num_states)
        for f_idx2 in ne_var[v_idx]:
            if f_idx2 != f_idx:
                msg_vf[(v_idx,f_idx)] += msg_fv[(f_idx2,v_idx)]
                
        # normalize
        msg_vf[(v_idx,f_idx)] = msg_vf[(v_idx,f_idx)] - np.mean(msg_vf[(v_idx,f_idx)])
        
# calculate max-marginals (num_vars x num_states matrix)
max_marginals = np.zeros([num_vars,num_states])
for v_idx in range(num_vars):
    
    # add messages from all factors sent to this variable
    max_marginals[v_idx] = np.zeros(num_states)
    for f_idx in ne_var[v_idx]:
        max_marginals[v_idx] += msg_fv[(f_idx,v_idx)]
    #print max_marginals[v_idx]

# get MAP solution
map_est = np.argmax(max_marginals,axis=1)

# plot MAP estimate
plt.imshow(map_est.reshape(h,w),interpolation='nearest');
plt.gray()
plt.show()
# Out:
# Messages initialized!
